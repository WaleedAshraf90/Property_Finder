# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import time
import sqlite3

sns.set(rc={'figure.figsize': [17, 17]}, font_scale=1.2)

# %% [markdown]
# <b> Load Data<b>

# %%
df2=pd.read_csv('property_finder.csv')
df2.head()
# Out:
#    Unnamed: 0        Type                                              Title  \
# 0           0      Chalet   Chalet + 120m Roof | Sea and Pool View | 3rd Row
# 1           1   Apartment  Apartment in new capital way new capital compo...
# 2           2       Villa  Corner villa |970 M |Practice Golf |Michael Gr...
# 3           3  Twin House  Panoramic sea view twin first row for sale LAV...
# 4           4       Villa  Own a panoramic villa|Enjoy in Lake West 2 |10...
#
#                                             Location    Bedrooms    Bathrooms  \
# 0  La Vista Bay, La Vista, Qesm Ad Dabaah, North ...  4 bedrooms  3 bathrooms
# 1                        R7, New Capital City, Cairo  4 bedrooms  3 bathrooms
# 2  Allegria, Sheikh Zayed Compounds, Sheikh Zayed...  4 bedrooms  5 bathrooms
# 3  La Vista Bay, La Vista, Qesm Ad Dabaah, North ...  4 bedrooms  4 bathrooms
# 4  Lake West, Sheikh Zayed Compounds, Sheikh Zaye...  6 bedrooms  6 bathrooms
#
#      Space           Price
# ...

# %% [markdown]
# <b> Prints information about the DataFrame</b>

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6975 entries, 0 to 6974
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  6975 non-null   int64
#  1   Type        6975 non-null   object
#  2   Title       6900 non-null   object
#  3   Location    6975 non-null   object
#  4   Bedrooms    6839 non-null   object
#  5   Bathrooms   6960 non-null   object
#  6   Space       6933 non-null   object
#  7   Price       6975 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 436.1+ KB

# %%
df2.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df=df2.dropna()
df
# Out:
#             Type                                              Title  \
# 0         Chalet   Chalet + 120m Roof | Sea and Pool View | 3rd Row
# 1      Apartment  Apartment in new capital way new capital compo...
# 2          Villa  Corner villa |970 M |Practice Golf |Michael Gr...
# 3     Twin House  Panoramic sea view twin first row for sale LAV...
# 4          Villa  Own a panoramic villa|Enjoy in Lake West 2 |10...
# ...          ...                                                ...
# 6970   Apartment     Apartment for sale in Stone Residence compound
# 6971   Apartment         Ready to Move Apartment 200m 25% DP (JOYA)
# 6972      Chalet  One bedroom chalet in Azha Sokhna at a good price
# 6973   Apartment  Instant Delivery apartment 160m² in southern L...
# 6974   Apartment      Heliopolis Apartment 220m . Heliopolis Square
#
#                                                Location    Bedrooms  \
# 0     La Vista Bay, La Vista, Qesm Ad Dabaah, North ...  4 bedrooms
# ...

# %% [markdown]
# # Analysis

# %% [markdown]
# <b>Finds NULL values</b>

# %%
df['Title'].unique()
# Out:
# array(['Chalet + 120m Roof | Sea and Pool View | 3rd Row',
#        'Apartment in new capital way new capital compounds',
#        'Corner villa |970 M |Practice Golf |Michael Graves', ...,
#        'Apartment with 5% DP and 8 years Installments',
#        'Villa resale in Palm Hills Golf Extension',
#        'inst 8 years Apartment 225m in MV Icity'], dtype=object)

# %%
df.isnull().sum()*100/6725
# Out:
# Type         0.0
# Title        0.0
# Location     0.0
# Bedrooms     0.0
# Bathrooms    0.0
# Space        0.0
# Price        0.0
# dtype: float64

# %%
df['Type'].unique()
# Out:
# array(['Chalet', 'Apartment', 'Villa', 'Twin House', 'Penthouse',
#        'Townhouse', 'Duplex', 'Hotel Apartment', 'iVilla', 'Compound'],
#       dtype=object)

# %%
df['Type'].nunique()
# Out:
# 10

# %% [markdown]
# <b>the type count is 10</b>

# %%
df['Type'].value_counts()
# Out:
# Apartment          2244
# Villa              1583
# Chalet             1380
# Townhouse           542
# Twin House          397
# Duplex              229
# Penthouse           226
# iVilla               80
# Hotel Apartment      43
# Compound              1
# Name: Type, dtype: int64

# %% [markdown]
# <b> the most type is Apartment andApartment andChalet</b>

# %%
df['Title'].nunique()
# Out:
# 5043

# %% [markdown]
# <b>the title count 5043</b>

# %%
df['Title'].value_counts()
# Out:
# Villa for sale In Lake View L:600 BUE:550 price18M    8
# Own a panoramic villa|Enjoy in Lake West 2 |10% DP    6
# studio for sale in hyde park under market price       6
# Villa installments up to 10 years in Badyã            5
# Apartment for sale in Zahraa El Maadi                 5
#                                                      ..
# Island Villa for sale in Azha Prime location          1
# Corner APT 239M inst. till 2026 Mivida Boulevard.     1
# Own villa in O West Compound, with 10% DP over 7Y     1
# Twin House for sale at Hacienda Bay                   1
# TwinHouse / HydePark / Modern / installments          1
# Name: Title, Length: 5043, dtype: int64

# %% [markdown]
# <b> the most TiTle is =>Villa for sale In Lake View L:600 BUE:550 price18M  &studio for sale in hyde park under market price<b>

# %%
df['Location'].unique()
# Out:
# array(['La Vista Bay, La Vista, Qesm Ad Dabaah, North Coast',
#        'R7, New Capital City, Cairo',
#        'Allegria, Sheikh Zayed Compounds, Sheikh Zayed City, Giza',
#        'Lake West, Sheikh Zayed Compounds, Sheikh Zayed City, Giza',
#        'Marassi, Sidi Abdel Rahman, North Coast',
#        'Caesar, Qesm Marsa Matrouh, North Coast',
#        'Ahmed Orabi St., Rehab City Forth Phase, Al Rehab, New Cairo City, Cairo',
#        'Hyde Park, 5th Settlement Compounds, The 5th Settlement, New Cairo City, Cairo',
#        'Layan Residence, 5th Settlement Compounds, The 5th Settlement, New Cairo City, Cairo',
#        'Terencia, Uptown Cairo, Mokattam, Cairo',
#        'Amwaj, Al Alamein, North Coast',
#        'Fifth Square, North Investors Area, New Cairo City, Cairo',
#        'Albert Al Awal St., Smouha, Hay Sharq, Alexandria',
#        'Al Rabwa, Sheikh Zayed Compounds, Sheikh Zayed City, Giza',
# ...

# %%
df['Location'].nunique()
# Out:
# 674

# %% [markdown]
# <b> the loctaion count is 674<b>

# %%
df['Location'].value_counts()
# Out:
# Marassi, Sidi Abdel Rahman, North Coast                                                 493
# Hyde Park, 5th Settlement Compounds, The 5th Settlement, New Cairo City, Cairo          233
# Mivida, 5th Settlement Compounds, The 5th Settlement, New Cairo City, Cairo             202
# Mountain View, Ras Al Hekma, North Coast                                                163
# Hacienda Bay, Sidi Abdel Rahman, North Coast                                            149
#                                                                                        ...
# Makadi, Hurghada, Red Sea                                                                 1
# Zamalek, Cairo                                                                            1
# Holiday Fantasia, Ras Sedr, South Sainai                                                  1
# Al Feda Gardens, 5th Settlement Compounds, The 5th Settlement, New Cairo City, Cairo      1
# ...

# %% [markdown]
# <b>the most location is=>Marassi, Sidi Abdel Rahman, North Coast &Hyde Park, 5th Settlement Compounds, The 5th Settlement, New Cairo City, Cairo</>

# %%
df['Bedrooms'].unique()
# Out:
# array(['4 bedrooms', '6 bedrooms', '5 bedrooms', '1 bedroom',
#        '3 bedrooms', '2 bedrooms', '8 bedrooms', '7 bedrooms'],
#       dtype=object)

# %%
df['Bedrooms'].nunique()
# Out:
# 8

# %% [markdown]
# <b>The Bedrooms count is 8</b>

# %%
df['Bedrooms'].value_counts()
# Out:
# 3 bedrooms    2925
# 4 bedrooms    1412
# 2 bedrooms    1208
# 5 bedrooms     578
# 1 bedroom      283
# 6 bedrooms     221
# 8 bedrooms      53
# 7 bedrooms      45
# Name: Bedrooms, dtype: int64

# %% [markdown]
# <b>tthe most bedroms is 3&4&2</b>

# %%
df['Bathrooms'].unique()
# Out:
# array(['3 bathrooms', '5 bathrooms', '4 bathrooms', '6 bathrooms',
#        '1 bathroom', '7 bathrooms', '2 bathrooms', '8 bathrooms'],
#       dtype=object)

# %%
df['Bathrooms'].nunique()
# Out:
# 8

# %%
df['Bathrooms'].value_counts()
# Out:
# 3 bathrooms    2356
# 2 bathrooms    1743
# 4 bathrooms    1197
# 5 bathrooms     575
# 1 bathroom      482
# 6 bathrooms     183
# 7 bathrooms     120
# 8 bathrooms      69
# Name: Bathrooms, dtype: int64

# %%
df['Space'].unique()
# Out:
# array(['200 sqm', '260 sqm', '970 sqm', '320 sqm', '292 sqm', '623 sqm',
#        '73 sqm', '280 sqm', '210 sqm', '160 sqm', '283 sqm', '251 sqm',
#        '741 sqm', '115 sqm', '270 sqm', '240 sqm', '680 sqm', '285 sqm',
#        '780 sqm', '650 sqm', '227 sqm', '475 sqm', '860 sqm', '157 sqm',
#        '120 sqm', '72 sqm', '450 sqm', '307 sqm', '167 sqm', '140 sqm',
#        '1,550 sqm', '500 sqm', '600 sqm', '150 sqm', '238 sqm', '276 sqm',
#        '900 sqm', '202 sqm', '84 sqm', '670 sqm', '449 sqm', '133 sqm',
#        '220 sqm', '177 sqm', '188 sqm', '440 sqm', '264 sqm', '225 sqm',
#        '216 sqm', '523 sqm', '90 sqm', '420 sqm', '155 sqm', '145 sqm',
#        '250 sqm', '180 sqm', '170 sqm', '144 sqm', '129 sqm', '305 sqm',
#        '498 sqm', '248 sqm', '356 sqm', '208 sqm', '455 sqm', '156 sqm',
#        '56 sqm', '174 sqm', '245 sqm', '164 sqm', '110 sqm', '108 sqm',
#        '700 sqm', '173 sqm', '136 sqm', '490 sqm', '185 sqm', '190 sqm',
# ...

# %%
df['Space'].nunique()
# Out:
# 575

# %%
df['Space'].value_counts()
# Out:
# 200 sqm      140
# 150 sqm      129
# 160 sqm      129
# 140 sqm      115
# 180 sqm      114
#             ...
# 1,832 sqm      1
# 1,199 sqm      1
# 523 sqm        1
# 555 sqm        1
# 1,790 sqm      1
# Name: Space, Length: 575, dtype: int64

# %%
# int(df['Bedrooms'].iloc[2000].split(' ')[0])
# int(df['Bathrooms'].iloc[2000].split(' ')[0])

# %%
df['Bedrooms']=df['Bedrooms'].apply(lambda x: int(x.split(' ')[0]))
# Out:
# <ipython-input-26-d3943d9fb1f4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Bedrooms']=df['Bedrooms'].apply(lambda x: int(x.split(' ')[0]))

# %%
df['Bathrooms']=df['Bathrooms'].apply(lambda x: int(x.split(' ')[0]))
# Out:
# <ipython-input-27-a92e8e4b3f05>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Bathrooms']=df['Bathrooms'].apply(lambda x: int(x.split(' ')[0]))

# %%
def fixed(x):
     try:
        y=str(x) 
        return float(y.split(" ")[0])
     except:
        return np.nan

df['Space']=df['Space'].apply(fixed)
# Out:
# <ipython-input-28-589cffcd2451>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Space']=df['Space'].apply(fixed)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6725 entries, 0 to 6974
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Type       6725 non-null   object
#  1   Title      6725 non-null   object
#  2   Location   6725 non-null   object
#  3   Bedrooms   6725 non-null   int64
#  4   Bathrooms  6725 non-null   int64
#  5   Space      6599 non-null   float64
#  6   Price      6725 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 420.3+ KB

# %%
df
# Out:
#             Type                                              Title  \
# 0         Chalet   Chalet + 120m Roof | Sea and Pool View | 3rd Row
# 1      Apartment  Apartment in new capital way new capital compo...
# 2          Villa  Corner villa |970 M |Practice Golf |Michael Gr...
# 3     Twin House  Panoramic sea view twin first row for sale LAV...
# 4          Villa  Own a panoramic villa|Enjoy in Lake West 2 |10...
# ...          ...                                                ...
# 6970   Apartment     Apartment for sale in Stone Residence compound
# 6971   Apartment         Ready to Move Apartment 200m 25% DP (JOYA)
# 6972      Chalet  One bedroom chalet in Azha Sokhna at a good price
# 6973   Apartment  Instant Delivery apartment 160m² in southern L...
# 6974   Apartment      Heliopolis Apartment 220m . Heliopolis Square
#
#                                                Location  Bedrooms  Bathrooms  \
# ...

# %%
df['Price'].unique()
# Out:
# array(['Ask for price', '7,418,000 EGP', '19,000,000 EGP', ...,
#        '176,000 EGP', '304,999 EGP', '499,998 EGP'], dtype=object)

# %%
df['Price']=df['Price'].replace('Ask for price','0')
# Out:
# <ipython-input-32-0217b36692f0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price']=df['Price'].replace('Ask for price','0')

# %%
list(df['Price'])
# Out:
# ['0',
#  '7,418,000 EGP',
#  '19,000,000 EGP',
#  '9,500,000 EGP',
#  '7,100,000 EGP',
#  '25,300,000 EGP',
#  '0',
#  '43,000,000 EGP',
#  '3,500,000 EGP',
#  '350,000 EGP',
#  '6,700,000 EGP',
#  '20,500,000 EGP',
#  '33,000,000 EGP',
#  '3,037,000 EGP',
#  '5,200,000 EGP',
#  '4,700,000 EGP',
#  '12,000,000 EGP',
#  '3,700,000 EGP',
#  '8,200,000 EGP',
#  '12,000,000 EGP',
#  '7,500,000 EGP',
#  '13,000,000 EGP',
#  '4,800,000 EGP',
#  '552,000 EGP',
#  '14,000,000 EGP',
#  '552,000 EGP',
#  '14,000,000 EGP',
#  '9,000,000 EGP',
#  '1,749,690 EGP',
#  '2,850,000 EGP',
#  '1,899,000 EGP',
#  '12,500,000 EGP',
#  '1,700,000 EGP',
#  '9,899,999 EGP',
#  '3,550,000 EGP',
#  '4,500,000 EGP',
#  '1,400,000 EGP',
#  '45,000,000 EGP',
#  '5,600,000 EGP',
#  '25,000,000 EGP',
#  '4,800,000 EGP',
#  '919,000 EGP',
#  '3,117,000 EGP',
#  '18,000,000 EGP',
#  '4,704,000 EGP',
#  '5,150,000 EGP',
#  '7,400,000 EGP',
#  '7,687,000 EGP',
#  '2,400,000 EGP',
#  '14,000,000 EGP',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6725 entries, 0 to 6974
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Type       6725 non-null   object
#  1   Title      6725 non-null   object
#  2   Location   6725 non-null   object
#  3   Bedrooms   6725 non-null   int64
#  4   Bathrooms  6725 non-null   int64
#  5   Space      6599 non-null   float64
#  6   Price      6725 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 420.3+ KB

# %%
df['Price'].iloc[900].split(' ')[0]
# Out:
# '5,150,000'

# %%
df['Price']=df['Price'].apply(lambda x: x.split(' ')[0])
# Out:
# <ipython-input-36-c6f7b9dd1f59>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price']=df['Price'].apply(lambda x: x.split(' ')[0])

# %%
df
# Out:
#             Type                                              Title  \
# 0         Chalet   Chalet + 120m Roof | Sea and Pool View | 3rd Row
# 1      Apartment  Apartment in new capital way new capital compo...
# 2          Villa  Corner villa |970 M |Practice Golf |Michael Gr...
# 3     Twin House  Panoramic sea view twin first row for sale LAV...
# 4          Villa  Own a panoramic villa|Enjoy in Lake West 2 |10...
# ...          ...                                                ...
# 6970   Apartment     Apartment for sale in Stone Residence compound
# 6971   Apartment         Ready to Move Apartment 200m 25% DP (JOYA)
# 6972      Chalet  One bedroom chalet in Azha Sokhna at a good price
# 6973   Apartment  Instant Delivery apartment 160m² in southern L...
# 6974   Apartment      Heliopolis Apartment 220m . Heliopolis Square
#
#                                                Location  Bedrooms  Bathrooms  \
# ...

# %%
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
#df['Price'] = df['Price'].astype('float64') 
#df['Price'] = pd.to_numeric(df['Price'])
#df['Price'] = df['Price'].convert_objects(convert_numeric=True)
# Out:
# <ipython-input-44-88cb0809d7c8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

# %%
# Out:
# [0.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  0.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6725 entries, 0 to 6974
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Type       6725 non-null   object
#  1   Title      6725 non-null   object
#  2   Location   6725 non-null   object
#  3   Bedrooms   6725 non-null   int64
#  4   Bathrooms  6725 non-null   int64
#  5   Space      6599 non-null   float64
#  6   Price      158 non-null    float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 420.3+ KB

# %%
df
# Out:
#             Type                                              Title  \
# 0         Chalet   Chalet + 120m Roof | Sea and Pool View | 3rd Row
# 1      Apartment  Apartment in new capital way new capital compo...
# 2          Villa  Corner villa |970 M |Practice Golf |Michael Gr...
# 3     Twin House  Panoramic sea view twin first row for sale LAV...
# 4          Villa  Own a panoramic villa|Enjoy in Lake West 2 |10...
# ...          ...                                                ...
# 6970   Apartment     Apartment for sale in Stone Residence compound
# 6971   Apartment         Ready to Move Apartment 200m 25% DP (JOYA)
# 6972      Chalet  One bedroom chalet in Azha Sokhna at a good price
# 6973   Apartment  Instant Delivery apartment 160m² in southern L...
# 6974   Apartment      Heliopolis Apartment 220m . Heliopolis Square
#
#                                                Location  Bedrooms  Bathrooms  \
# ...

# %%
df.info()
